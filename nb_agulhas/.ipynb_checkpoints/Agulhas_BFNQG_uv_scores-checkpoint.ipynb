# %% [markdown]
# ![header](../figures/logos_partenaires_DC_WOC-ESA.jpg)

# %% [markdown]
# # Agulhas: Benchmark BFN-QG geostrophic currents maps
#
#
# ***
# **Authors:** Datlas <br>
# **Copyright:** 2023 Datlas <br>
# **License:** MIT
#
# <div class="alert alert-block alert-success">
# <h1><center>Agulhas: Benchmark of BFN-QG geostrophic currents maps</center></h1>
#  <h5><center> The notebook aims to evaluate the surface current maps produced by the BFN-QG system in the Agulhas region.</center></h5>

# %% [markdown]
# ***
# **General Note 1**: Execute each cell through the <button class="btn btn-default btn-xs"><i class="icon-play fa fa-play"></i></button> button from the top MENU (or keyboard shortcut `Shift` + `Enter`).<br>
# <br>
# **General Note 2**: If, for any reason, the kernel is not working anymore, in the top MENU, click on the <button class="btn btn-default btn-xs"><i class="fa fa-repeat icon-repeat"></i></button> button. Then, in the top MENU, click on "Cell" and select "Run All Above Selected Cell".<br>
# ***
#
#
# <div class="alert alert-danger" role="alert">
#
# <h3>Learning outcomes</h3>
#
# At the end of this notebook you will know:
# <ul>
#   <li>How you can evaluated Sea surface currents maps with drifters database: statistical and spectral analysis</li>
# </ul>
#
# </div>

# %%
from glob import glob
import numpy as np
import os
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append('..')
from src.mod_plot import *
from src.mod_stat import *
from src.mod_spectral import *
from src.mod_interp import *

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>0. Parameters</h2>
#
# </div>

# %%
time_min = '2019-01-01'                                        # time min for analysis
time_max = '2019-12-31'                                        # time max for analysis
output_dir = '../results'                                      # output directory path
os.system(f'mkdir -p {output_dir}')

# Region details
region = 'Agulhas'
lon_min = 14                                          # domain min longitude
lon_max = 35                                          # domain max longitude
lat_min = -45.                                          # domain min latitude
lat_max = -25.                                          # domain max latitude

box_lonlat = {'lon_min':lon_min,'lon_max':lon_max,'lat_min':lat_min,'lat_max':lat_max}

method_name = 'BFNQG'

stat_output_filename = f'{output_dir}/stat_uv_bfnqg_Agulhas.nc'   # output statistical analysis filename
psd_output_filename = f'{output_dir}/psd_uv_bfnqg_Agulhas.nc'     # output spectral analysis filename
segment_lenght = np.timedelta64(40, 'D')                      # spectral parameter: drifters segment lenght in days to consider in the spectral analysis

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>1. Input files</h2>
#
# </div>

# %% [markdown]
# ## [Sea Surface currents from Drifters database](https://doi.org/10.17882/86236)

# %%
filenames_drifters = sorted(glob('../data/independant_eval/indep_drifters_Agulhas.nc'))

# %%
ds_drifter = xr.open_mfdataset(filenames_drifters, combine='nested', concat_dim='time')
ds_drifter = ds_drifter.where((ds_drifter.time >= np.datetime64(time_min)) & (ds_drifter.time <=  np.datetime64(time_max)), drop=True)
ds_drifter
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 19148)
# Coordinates:
#   * time       (time) datetime64[ns] 2019-01-01 2019-01-01 ... 2019-12-31
#     latitude   (time) float32 dask.array<chunksize=(19148,), meta=np.ndarray>
#     longitude  (time) float32 dask.array<chunksize=(19148,), meta=np.ndarray>
# Data variables:
#     EWCT       (time) float32 dask.array<chunksize=(19148,), meta=np.ndarray>
#     NSCT       (time) float32 dask.array<chunksize=(19148,), meta=np.ndarray>
#     sensor_id  (time) float64 dask.array<chunksize=(19148,), meta=np.ndarray>
# Attributes: (12/46)
#     data_type:                   OceanSITES trajectory data
#     format_version:              2.0
#     platform_code:               116275
#     date_update:                 2020-10-13T12:17:40Z
#     institution:                 AOML
#     institution_edmo_code:       1799
#     ...                          ...
#     deployment_lat:              -58.44
#     last_longitude_observation:  82.75
#     last_latitude_observation:   -18.49
#     date_drog_lost:              2017-01-21T03:37:00Z
#     death_type:                  stop transmitting
#     last_date_observation:       2019-01-16T01:51:00Z

# %% [markdown]
# ## Sea Surface current maps to evaluate

# %%
list_of_maps = sorted(glob('../data/maps/DC_WOC-ESA_Agulhas_2019_BFNQG/BFNQG_WOC_Ugeo_2019*'))
ds_maps = xr.open_mfdataset(list_of_maps, combine='nested', concat_dim='time')
ds_maps = ds_maps.sel(time=slice(time_min, time_max))
ds_maps = ds_maps.resample(time='1D').mean(dim='time')
ds_maps = ds_maps.rename_vars({'ug':'ugos','vg':'vgos'})
ds_maps
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 365, latitude: 201, longitude: 301)
# Coordinates:
#   * longitude  (longitude) float32 10.0 10.1 10.2 10.3 ... 39.7 39.8 39.9 40.0
#   * latitude   (latitude) float32 -45.0 -44.9 -44.8 -44.7 ... -25.2 -25.1 -25.0
#   * time       (time) datetime64[ns] 2019-01-01 2019-01-02 ... 2019-12-31
# Data variables:
#     ugos       (time, latitude, longitude) float32 dask.array<chunksize=(1, 201, 301), meta=np.ndarray>
#     vgos       (time, latitude, longitude) float32 dask.array<chunksize=(1, 201, 301), meta=np.ndarray>
# Attributes: (12/50)
#     Conventions:                 CF-1.7, ACDD-1.3, ISO 8601
#     Metadata_Conventions:        Climate and Forecast (CF) 1.7, Attribute Con...
#     standard_name_vocabulary:    NetCDF Climate and Forecast (CF) Metadata Co...
#     title:                       Geostrophic surface current over the Agulhas...
#     summary:                     This dataset contains the geostrophic surfac...
#     id:                          WOC-L4-geo-BFNQG-Agh
#     ...                          ...
#     date_modified:               11/05/2022
#     source:
#     source_version:
#     history:
#     input:                       CMEMS dt_global_allsat_phy_l3
#     processing_software:

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# <h2>2. Statistical & Spectral Analysis </h2>
#
# </div>

# %% [markdown]
# ## 2.1 Interpolate sea surface currents maps onto drifters positions

# %%
ds_interp = run_interpolation_drifters(ds_maps, ds_drifter, time_min, time_max)
ds_interp = ds_interp.dropna('time')
ds_interp = ds_interp.sortby('time')
ds_interp
# Out:
# 2023-11-06 15:18:52 INFO     fetch data from 2019-01-01 00:00:00 to 2019-02-01 00:00:00
# 2023-11-06 15:18:52 INFO     fetch data from 2019-01-01 00:00:00 to 2019-02-01 00:00:00
# 2023-11-06 15:18:52 INFO     fetch data from 2019-01-31 00:00:00 to 2019-03-01 00:00:00
# 2023-11-06 15:18:52 INFO     fetch data from 2019-01-31 00:00:00 to 2019-03-01 00:00:00
# 2023-11-06 15:18:53 INFO     fetch data from 2019-02-28 00:00:00 to 2019-04-01 00:00:00
# 2023-11-06 15:18:53 INFO     fetch data from 2019-02-28 00:00:00 to 2019-04-01 00:00:00
# 2023-11-06 15:18:53 INFO     fetch data from 2019-03-31 00:00:00 to 2019-05-01 00:00:00
# 2023-11-06 15:18:53 INFO     fetch data from 2019-03-31 00:00:00 to 2019-05-01 00:00:00
# 2023-11-06 15:18:53 INFO     fetch data from 2019-04-30 00:00:00 to 2019-06-01 00:00:00
# 2023-11-06 15:18:54 INFO     fetch data from 2019-04-30 00:00:00 to 2019-06-01 00:00:00
# 2023-11-06 15:18:54 INFO     fetch data from 2019-05-31 00:00:00 to 2019-07-01 00:00:00
# 2023-11-06 15:18:55 INFO     fetch data from 2019-05-31 00:00:00 to 2019-07-01 00:00:00
# 2023-11-06 15:18:55 INFO     fetch data from 2019-06-30 00:00:00 to 2019-08-01 00:00:00
# 2023-11-06 15:18:55 INFO     fetch data from 2019-06-30 00:00:00 to 2019-08-01 00:00:00
# 2023-11-06 15:18:55 INFO     fetch data from 2019-07-31 00:00:00 to 2019-09-01 00:00:00
# 2023-11-06 15:18:56 INFO     fetch data from 2019-07-31 00:00:00 to 2019-09-01 00:00:00
# 2023-11-06 15:18:56 INFO     fetch data from 2019-08-31 00:00:00 to 2019-10-01 00:00:00
# 2023-11-06 15:18:56 INFO     fetch data from 2019-08-31 00:00:00 to 2019-10-01 00:00:00
# 2023-11-06 15:18:56 INFO     fetch data from 2019-09-30 00:00:00 to 2019-11-01 00:00:00
# 2023-11-06 15:18:57 INFO     fetch data from 2019-09-30 00:00:00 to 2019-11-01 00:00:00
# 2023-11-06 15:18:57 INFO     fetch data from 2019-10-31 00:00:00 to 2019-12-01 00:00:00
# 2023-11-06 15:18:57 INFO     fetch data from 2019-10-31 00:00:00 to 2019-12-01 00:00:00
# 2023-11-06 15:18:58 INFO     fetch data from 2019-11-30 00:00:00 to 2019-12-31 00:00:00
# 2023-11-06 15:18:58 INFO     fetch data from 2019-11-30 00:00:00 to 2019-12-31 00:00:00
# <xarray.Dataset>
# Dimensions:            (time: 18725)
# Coordinates:
#   * time               (time) datetime64[ns] 2019-01-01 ... 2019-12-31
# Data variables:
#     EWCT               (time) float32 0.2473 0.2699 0.2135 ... -0.3408 0.1364
#     NSCT               (time) float32 0.2808 -0.4458 -0.00036 ... 0.1347 0.03685
#     sensor_id          (time) float64 6.076e+07 6.368e+07 ... 6.662e+07 6.72e+07
#     latitude           (time) float32 -38.78 -37.01 -32.82 ... -39.49 -31.58
#     longitude          (time) float32 23.84 26.34 32.72 ... 22.55 33.83 32.49
#     ugos_interpolated  (time) float64 0.009526 0.3416 0.1006 ... -0.2881 0.3078
#     vgos_interpolated  (time) float64 0.03214 -1.182 0.08573 ... -0.104 0.004039

# %% [markdown]
# ## 2.2 Compute grid boxes statistics & statistics by regime (coastal, offshore low variability, offshore high variability)

# %% [markdown]
# Once the surface currents maps have been interpolated to the position of the drifters, it is possible to calculate different statistics on the time series of zonal and meridional velocities.
#
# We propose below the following statistics: error variance maps (static by 1°x1° box), explained variance maps.

# %%
# Compute gridded stats
compute_stat_scores_uv(ds_interp, stat_output_filename,method_name=method_name)
# Out:
# 2023-11-06 15:18:58 INFO     Compute mapping error all scales
# 2023-11-06 15:18:58 INFO     Compute statistics
# 2023-11-06 15:19:00 INFO     Stat file saved as: ../results/stat_uv_bfnqg_Agulhas.nc
# 2023-11-06 15:19:00 INFO     Compute statistics by oceanic regime

# %%
# Plot gridded stats
# Hvplot
# plot_stat_score_map_uv(stat_output_filename)
# Matplotlib
plot_stat_score_map_uv_png(stat_output_filename,region=region,box_lonlat=box_lonlat)

# %% [markdown]
# The figure shows that the maximum mapping errors are found in intense current systems, for example in the GulfStream, Kuroshio and Agulhas regions.
#
# However, when considering the full scale of motion in the drifter database, the surface current maps capture up to 80% of the variability of drifter currents in the Western Boundary Currents and Antarctic Circumpolar Currents (ACC). The geostrophic signal dominates the ageostrophic signal in these regions. In regions with low ocean variability, only a few percent of the total drifter current variability is recovered in the maps, which may be associated with a larger ageostrophic signal in these regions.

# %%
plot_stat_uv_by_regimes(stat_output_filename)
# Out:
#                   mapping_err_u_var [m²/s²]  mapping_err_v_var [m²/s²]  \
# coastal                            0.053070                   0.047112
# offshore_highvar                   0.046895                   0.048429
# offshore_lowvar                    0.023079                   0.020393
# equatorial_band                         NaN                        NaN
# arctic                                  NaN                        NaN
# antarctic                               NaN                        NaN
#
#                   ugos_interpolated_var [m²/s²]  EWCT_var [m²/s²]  \
# coastal                                0.113879          0.197969
# offshore_highvar                       0.162661          0.209670
# offshore_lowvar                        0.025797          0.052599
# equatorial_band                             NaN               NaN
# arctic                                      NaN               NaN
# antarctic                                   NaN               NaN
#
#                   vgos_interpolated_var [m²/s²]  NSCT_var [m²/s²]  \
# coastal                                0.088778          0.153333
# offshore_highvar                       0.145381          0.185046
# offshore_lowvar                        0.026280          0.048567
# equatorial_band                             NaN               NaN
# arctic                                      NaN               NaN
# antarctic                                   NaN               NaN
#
#                   var_score_u_allscale  var_score_v_allscale
# coastal                       0.731929              0.692748
# offshore_highvar              0.776340              0.738286
# offshore_lowvar               0.561225              0.580100
# equatorial_band                    NaN                   NaN
# arctic                             NaN                   NaN
# antarctic                          NaN                   NaN

# %% [markdown]
# ## 2.4 Compute Spectral scores

# %%
# Compute PSD scores
compute_psd_scores_current(ds_interp, psd_output_filename, lenght_scale=segment_lenght, method_name=method_name)
# Out:
# 2023-11-06 15:19:33 INFO     Segment computation...
# 2023-11-06 15:19:33 INFO     Spectral analysis...
# 2023-11-06 15:19:33 INFO     Write output...
# 2023-11-06 15:19:33 INFO     PSD file saved as: ../results/psd_uv_bfnqg_Agulhas.nc

# %%
# Plot Zonally averaged rotary spectra
# Hvplot
# plot_psd_scores_currents(psd_output_filename)
# Matplotlib
plot_psd_scores_currents_png(psd_output_filename,region=region)

# %%
# Plot Zonally averaged rotary spectra
plot_psd_scores_currents_1D(psd_output_filename)
# Out:
# :Layout
#    .DynamicMap.I  :DynamicMap   [lat]
#       :Overlay
#          .Curve.PSD_drifters :Curve   [wavenumber]   (psd_ref)
#          .Curve.PSD_maps     :Curve   [wavenumber]   (psd_study)
#    .DynamicMap.II :DynamicMap   [lat]
#       :Overlay
#          .Curve.Coherence           :Curve   [wavenumber]   (coherence)
#          .Curve.PSD_err_over_PSDref :Curve   [wavenumber]   (psd_err_psd_ref)

# %% [markdown]
# The interactive plot above allows you to explore the spectral metrics by latitude band
